# %%
import os
import math
import sys
import statsmodels.api as sm
import numpy as np
import seaborn as sns
import re
from functools import reduce
from operator import and_
import yfinance as yf
from functools import partial, reduce                                                                              
from statsmodels.stats.outliers_influence import variance_inflation_factor 
import datetime as dt
from pdb import set_trace as keyboard
import xlrd
from xlrd import open_workbook
from sklearn.decomposition import FastICA
import pandas as pd
pd.core.common.is_list_like = pd.api.types.is_list_like
from pandas_datareader import data as pdr
from tkinter import StringVar
import matplotlib.pyplot as plt
from sklearn import linear_model
clf = linear_model.LinearRegression()

import matplotlib

yf.pdr_override()

# %%
stockIndex = ['IBOV']
sectorIndexes = ['ICON', 'IEE', 'IFNC', 'IMAT', 'IMOB', 'INDX', 'UTIL']
otherIndices = ['IBOV','IBRX','IBRX_50','ICON','SMLL','ITAG','MLCX','IVBX2','IDIV','ICO2','IBrA','BDRX','ISE',]
#currencies = ['DOLAR', 'EURO']
currencies = ['DOLAR']

# %%
ltnExcelFile = 'assets\LTN.xls'
xl_ltn = pd.ExcelFile(ltnExcelFile)

ltn_dict = {}
for bond in xl_ltn.sheet_names:
    df = pd.read_excel(ltnExcelFile, sheet_name=bond, skiprows = 1, usecols='A, E', names=['Date', 'Value'],
                          index_col=0).pct_change()
    df.columns = [bond]
    ltn_dict[bond] = df
    
my_reduce = partial(pd.merge, on='Date', how='outer')                                                              
ltn_df = reduce(my_reduce, ltn_dict.values()) 
ltn_df.head()
# Out:
#             LTN 010120  LTN 010121  LTN 010122  LTN 010123  LTN 010125
# Date
# 02/01/2019         NaN         NaN         NaN         NaN         NaN
# 03/01/2019    0.001002    0.002885         NaN    0.005116    0.005291
# 04/01/2019   -0.000213   -0.001197         NaN   -0.002614   -0.003481
# 07/01/2019    0.000341    0.000276         NaN    0.001789    0.005839
# 08/01/2019   -0.000394   -0.001186         NaN   -0.000401   -0.000201

# %%
ntnbExcelFile = 'assets\\NTNB.xls'
xl_ntnb = pd.ExcelFile(ntnbExcelFile)

ntnb_dict = {}
for bond in xl_ntnb.sheet_names:
    df = pd.read_excel(ntnbExcelFile, sheet_name=bond, skiprows = 1, usecols='A, E', names=['Date', 'Value'],
                          index_col=0).pct_change()
    df.columns = [bond]
    ntnb_dict[bond] = df
                                                               
ntnb_df = reduce(my_reduce, ntnb_dict.values()) 
ntnb_df.head()
# Out:
#             NTN-B Princ 150519  NTN-B Princ 150824  NTN-B Princ 150535  \
# Date
# 02/01/2019                 NaN                 NaN                 NaN
# 03/01/2019            0.000557            0.003426            0.000227
# 04/01/2019            0.000713            0.001878           -0.004357
# 07/01/2019            0.000268            0.002882            0.020613
# 08/01/2019            0.000131            0.000743            0.008024
#
#             NTN-B Princ 150545
# Date
# 02/01/2019                 NaN
# 03/01/2019            0.000232
# 04/01/2019           -0.007193
# 07/01/2019            0.033289
# 08/01/2019            0.012823

# %%
remaining_dict = {}
for data in sectorIndexes + otherIndices + currencies:
    df = pd.read_excel(r"C:\Users\Faria\Desktop\Gerador\%s.xlsx" % data, usecols='D, F', index_col=0, 
                       names=['Date', 'Value'])
    df.columns = [data]
    remaining_dict[data] = df

remaining_df = reduce(my_reduce, remaining_dict.values()) 
remaining_df.head()
# Out:
#                 ICON       IEE      IFNC      IMAT      IMOB      INDX  \
# Date
# 03/10/2019  0.003358  0.003293  0.003147  0.003913  0.015404  0.000155
# 02/10/2019 -0.023761 -0.012623 -0.027843 -0.037146 -0.021169 -0.025562
# 01/10/2019 -0.002884 -0.003380 -0.012771 -0.006073 -0.007091 -0.000357
# 30/09/2019  0.002201  0.011030 -0.010629  0.001385  0.006149 -0.001815
# 27/09/2019 -0.002915 -0.001489 -0.002525 -0.000858 -0.004225 -0.006432
#
#                 UTIL      IBOV      IBRX   IBRX_50      SMLL      ITAG  \
# Date
# 03/10/2019  0.006385  0.004797  0.004930  0.004551  0.010058  0.005748
# 02/10/2019 -0.018020 -0.029042 -0.028130 -0.030315 -0.019857 -0.027727
# 01/10/2019 -0.003189 -0.006606 -0.006763 -0.006794 -0.004175 -0.007135
# 30/09/2019  0.012820 -0.003163 -0.002393 -0.004282  0.009784 -0.001698
# 27/09/2019 -0.001501 -0.002296 -0.002137 -0.002828  0.001674 -0.002067
#
#                 MLCX     IVBX2      IDIV      ICO2      IBrA      BDRX  \
# Date
# 03/10/2019  0.003996  0.006220  0.005042  0.004703  0.004705 -0.005936
# 02/10/2019 -0.028577 -0.023955 -0.022043 -0.027128 -0.027514 -0.021008
# 01/10/2019 -0.007056 -0.004946 -0.007460 -0.007278 -0.006716 -0.014181
# 30/09/2019 -0.003573  0.005228  0.006231 -0.006902 -0.001985  0.008228
# 27/09/2019 -0.002539 -0.002503  0.001872 -0.003458 -0.002085 -0.009258
#
#                  ISE     DOLAR
# Date
# 03/10/2019  0.004634 -0.012853
# 02/10/2019 -0.025412 -0.004648
# 01/10/2019 -0.009505  0.002305
# 30/09/2019  0.001978  0.001371
# 27/09/2019 -0.000758  0.002845

# %%
funds = ['05448587000110', 
         '11490618000101',
        '01214092000175', 
        '21624757000126', 
        '09528698000197', 
         '19419157000184', 
        '03168062000103', 
        '14812722000155', 
        '12987743000186']
fund_pctChange = pd.DataFrame({})

for fund in funds:
    fund_data_raw = pd.read_excel(r"C:\Users\Faria\Desktop\Gerador\%s.xlsx" % fund)

    fund_data = fund_data_raw
    fund_data['Data'] = fund_data['Data'].astype(str)
    fund_data['Data'] = pd.to_datetime(fund_data_raw['Data']).dt.strftime('%d/%m/%Y')
    fund_data.set_index('Data', inplace=True)
    fund_data.index.names = ['Date']
    df_temp = pd.DataFrame(fund_data['Variação'])
    df_temp.columns = [fund]
    
    if fund_pctChange.columns.size == 0:
        fund_pctChange = df_temp
    else:
        fund_pctChange = pd.merge(fund_pctChange, df_temp, on='Date', how='outer')

fund_pctChange.head()
# Out:
#             05448587000110  11490618000101  01214092000175  21624757000126  \
# Date
# 26/09/2019        0.001603        0.002368        0.000845        0.000868
# 25/09/2019        0.001468        0.000163       -0.000356        0.000939
# 24/09/2019       -0.001036       -0.000589        0.000753       -0.000203
# 23/09/2019       -0.000274       -0.000133       -0.001119       -0.000787
# 20/09/2019        0.002553        0.000649        0.000963        0.000570
#
#             09528698000197  19419157000184  03168062000103  14812722000155  \
# Date
# 26/09/2019        0.001474        0.002023        0.006821        0.003390
# 25/09/2019       -0.000949        0.004441       -0.002525       -0.002345
# 24/09/2019        0.000951       -0.002416       -0.007330        0.000447
# 23/09/2019        0.000155       -0.001570       -0.004515       -0.000699
# 20/09/2019        0.000563        0.005880        0.001412       -0.000214
#
#             12987743000186
# Date
# 26/09/2019       -0.000358
# 25/09/2019        0.008522
# 24/09/2019       -0.003350
# 23/09/2019       -0.005515
# 20/09/2019        0.017686

# %%
#nDays = 30
#endDate = dt.datetime.now()
#startDate = endDate - dt.timedelta(days=nDays)

# %%
X_data_raw = reduce(my_reduce, [fund_pctChange, ltn_df, ntnb_df, remaining_df]) # 
X_data_raw = X_data_raw.set_index(pd.to_datetime(X_data_raw.index, dayfirst=1))

#mask = X_data_raw.index > startDate

del X_data_raw['NTN-B Princ 150519']

del X_data_raw['NTN-B Princ 150824']
del X_data_raw['NTN-B Princ 150535']
del X_data_raw['NTN-B Princ 150545']
del X_data_raw['LTN 010120']
del X_data_raw['LTN 010121']
del X_data_raw['LTN 010122']
del X_data_raw['LTN 010123']
del X_data_raw['LTN 010125']

nDims = len(X_data_raw.columns)

#X_data = X_data_raw[mask]
X_data = X_data_raw[:26]

X_data = X_data.dropna()
len(X_data)
# Out:
# 20

# %%
X_data.head()
# Out:
#             05448587000110  11490618000101  01214092000175  21624757000126  \
# Date
# 2019-09-26        0.001603        0.002368        0.000845        0.000868
# 2019-09-25        0.001468        0.000163       -0.000356        0.000939
# 2019-09-24       -0.001036       -0.000589        0.000753       -0.000203
# 2019-09-23       -0.000274       -0.000133       -0.001119       -0.000787
# 2019-09-20        0.002553        0.000649        0.000963        0.000570
#
#             09528698000197  19419157000184  03168062000103  14812722000155  \
# Date
# 2019-09-26        0.001474        0.002023        0.006821        0.003390
# 2019-09-25       -0.000949        0.004441       -0.002525       -0.002345
# 2019-09-24        0.000951       -0.002416       -0.007330        0.000447
# 2019-09-23        0.000155       -0.001570       -0.004515       -0.000699
# 2019-09-20        0.000563        0.005880        0.001412       -0.000214
#
#             12987743000186      ICON  ...      SMLL      ITAG      MLCX  \
# Date                                  ...
# 2019-09-26       -0.000358  0.000233  ...  0.005517  0.008687  0.008269
# 2019-09-25        0.008522  0.002578  ... -0.002850  0.004445  0.005434
# 2019-09-24       -0.003350  0.010148  ... -0.003250 -0.006818 -0.007188
# 2019-09-23       -0.005515 -0.004373  ... -0.004215 -0.002425 -0.002038
# 2019-09-20        0.017686  0.006721  ... -0.000489  0.004751  0.004389
#
#                IVBX2      IDIV      ICO2      IBrA      BDRX       ISE  \
# Date
# 2019-09-26  0.003135  0.004859  0.009850  0.007937 -0.000617  0.004403
# 2019-09-25  0.002745 -0.003380  0.004982  0.004440  0.005278  0.001223
# 2019-09-24  0.000685 -0.005186 -0.006468 -0.006736 -0.011532 -0.007412
# 2019-09-23 -0.004033 -0.003320 -0.001571 -0.002303  0.004541 -0.002633
# 2019-09-20  0.004113 -0.001678  0.007593  0.003718 -0.006178  0.001020
#
#                DOLAR
# Date
# 2019-09-26 -0.008559
# 2019-09-25  0.002541
# 2019-09-24 -0.000311
# 2019-09-23  0.001127
# 2019-09-20  0.007103
#
# [5 rows x 29 columns]

# %%
class Results:
    def __init__(self, model, rsquared_adj, pvalues, coeffs_dict, selected_dimensions):
        self.model = model
        self.rsquared_adj = rsquared_adj
        self.pvalues = pvalues
        self.coeffs_dict = coeffs_dict
        self.selected_dimensions = selected_dimensions

# %%
X_total = X_data
len(X_total)
# Out:
# 20

# %%
nCols = X_total.columns.size
nCols
# Out:
# 29

# %%
from __future__ import print_function
import sys
import threading
from time import sleep
try:
    import thread
except ImportError:
    import _thread as thread
    
try:
    range, _print = xrange, print
    def print(*args, **kwargs): 
        flush = kwargs.pop('flush', False)
        _print(*args, **kwargs)
        if flush:
            kwargs.get('file', sys.stdout).flush()            
except NameError:
    pass

# %%
def quit_function(fn_name):
    # print to stderr, unbuffered in Python 2.
    print('{0} took too long'.format(fn_name), file=sys.stderr)
    sys.stderr.flush() # Python 3 stderr is likely buffered.
    thread.interrupt_main() # raises KeyboardInterrupt

def exit_after(s):
    '''
    use as decorator to exit process if 
    function takes longer than s seconds
    '''
    def outer(fn):
        def inner(*args, **kwargs):
            timer = threading.Timer(s, quit_function, args=[fn.__name__])
            timer.start()
            try:
                result = fn(*args, **kwargs)
            finally:
                timer.cancel()
            return result
        return inner
    return outer

# %%
from pdb import set_trace as keyboard
from operator import attrgetter
import time


@exit_after(2)
def custom_fit(y, X):
    return sm.OLS(endog=y, exog=X.values).fit()

"""
import warnings
warnings.simplefilter('error')
"""

list_of_sensibilities = []
dic_r2adj = {}
results_dict = {}

X_total_model = X_total.copy().iloc[:, len(funds):]
X_total_model['Bias'] = 1.

predef_dimensions = {}
for fund in funds:
    predef_dimensions[fund] = []
predef_dimensions['19419157000184'] = list(ltn_df.keys()) + list(ntnb_df.keys())
predef_dimensions['12987743000186'] = ['DOLAR']

dimensions_to_sample = [x for x in X_total_model.columns if not x in predef_dimensions]


N = 1000
minNumberDimensions = 6
sensitivity = .10

useBias = 1
nDays = len(X_total)
nDays_min = 15

for index_fund, fund in enumerate(funds):

    result_list = []
    rsquared_ajd_list = []

    for iteration in range(N):
        #keyboard()

        
        sampled_days = np.sort(np.random.choice(list(range(nDays)), size=np.random.randint(nDays_min, nDays), replace=False)).tolist()
        
        X_total_model_sampled = X_total_model.iloc[sampled_days]
        y = X_total[fund].iloc[sampled_days]
        
        #size_samples = np.random.randint(len(X_data)-2, len(X_data), size=N)
        size_samples = [min(len(X_total_model_sampled.columns), len(X_total_model_sampled))]*N
        
        if iteration % 10 == 0:
            #sys.stdout.write("\rIteration number {} ({}/{}), Number days: {}".format(iteration, index_fund+1, len(funds), len(X_total_model_sampled)))
            sys.stdout.write("\rIteration number {} ({}/{})".format(iteration, index_fund+1, len(funds)))
            sys.stdout.flush()
            
        while True:
            
            try:
                selected_dimensions = list(set(\
                    np.random.choice(dimensions_to_sample, size=size_samples[iteration], replace=False).tolist() + \
                    predef_dimensions[fund]))
            except:
                keyboard()

            if useBias:
                 selected_dimensions += ['Bias']

            X = X_total_model_sampled[selected_dimensions]

            tinicial = time.time()
            
            regressor_OLS = custom_fit(y, X)  
            pvalues_dict = dict(zip(selected_dimensions, regressor_OLS.pvalues))
            coeffs_dict  = dict(zip(selected_dimensions, regressor_OLS.params))
            
            try:
                i=0
                while max(list(pvalues_dict.values())) > sensitivity or math.isnan(regressor_OLS.rsquared_adj):
                    i += 1
                    dimensions_bigPvalue = \
                                list({ key:value for (key,value) in pvalues_dict.items() if value > sensitivity or math.isnan(value)}.keys())
                    if 'Bias' in dimensions_bigPvalue:
                        dimensions_bigPvalue.remove('Bias')
                    if dimensions_bigPvalue == []:
                        break
                    dimensionToRemove = np.random.choice(dimensions_bigPvalue)
                    selected_dimensions.remove(dimensionToRemove)
                    #stocks_bigPvalue.remove(stockToRemove)
                    del X[dimensionToRemove]
                    #sys.stdout.write("\rIteration number {} ({}/{})".format(iteration, len(dimensions_bigPvalue), len(dimensionToRemove)))
                    #sys.stdout.flush()
                    regressor_OLS = custom_fit(y, X)  
                    pvalues_dict = dict(zip(selected_dimensions, regressor_OLS.pvalues))
                    coeffs_dict  = dict(zip(selected_dimensions, regressor_OLS.params))
                    if len(pvalues_dict) == minNumberDimensions:
                        break
                    

            except Exception as e:
                print(e)
                keyboard()
                continue
               
            rsquared_adj = regressor_OLS.rsquared_adj
            
            if i == 0 and 0:
                keyboard()
            if not math.isnan(rsquared_adj) and np.abs([k for k in coeffs_dict.values()]).max() <= 1.5:
                result_list.append(Results(regressor_OLS,
                                   rsquared_adj, 
                                   pvalues_dict, 
                                   coeffs_dict,    
                                   selected_dimensions))

            if len(pvalues_dict) > 0:
                break


    result_list.sort(key=lambda x: x.rsquared_adj, reverse=True)
    best_rsquaredAdj_obj = result_list[0]

    #rint('\nNumber of dimensions: %s' % len(best_rsquaredAdj_obj.selected_dimensions))
    #rint('\nDimensions: %s' % best_rsquaredAdj_obj.selected_dimensions)
    #rint('\nR2 adj: %s' % best_rsquaredAdj_obj.rsquared_adj)
    #print('\np-values: %s' % pd.DataFrame(best_rsquaredAdj_obj.pvalues.values(), list(best_rsquaredAdj_obj.pvalues.keys())))
    #print('\nParams: %s' % best_rsquaredAdj_obj.model.summary(xname=best_rsquaredAdj_obj.selected_dimensions))

    """
    fig, ax = plt.subplots()
    fittedValues = X_total_model[best_rsquaredAdj_obj.selected_dimensions].multiply(best_rsquaredAdj_obj.model.params.values).sum(axis=1).values
    sns.scatterplot(range(len(y)), y, ax=ax)
    sns.scatterplot(range(len(fittedValues)), fittedValues, marker='+', color='red', ax=ax)
    """

    df_topR2 = pd.DataFrame(result_list[0].coeffs_dict.values(), list(result_list[0].coeffs_dict.keys()))
    if False:
        for i in range(1, len(result_list)):
            if result_list[i].rsquared_adj < .99:
                break
            p_values = pd.DataFrame(result_list[i].coeffs_dict.values(), list(result_list[i].coeffs_dict.keys()))
            df_topR2 = pd.concat((df_topR2, p_values))

    by_row_index = df_topR2.groupby(df_topR2.index)
    df_means = by_row_index.mean()

    list_of_sensibilities.append(pd.DataFrame(df_means.transpose()))
    list_of_sensibilities[-1].index = [fund]
    
    dic_r2adj[fund] = result_list[0].rsquared_adj
    results_dict[fund] = result_list
# Out:
# Iteration number 0 (6/9)9)> <ipython-input-103-4f63520c2337>(70)<module>()
# -> if useBias:
# (Pdb)  predef_dimensions[fund]
# (['LTN 010120', 'LTN 010121', 'LTN 010122', 'LTN 010123', 'LTN 010125', 'NTN-B Princ 150519', 'NTN-B Princ 150824', 'NTN-B Princ 150535', 'NTN-B Princ 150545'],)
# (Pdb)  q
# --KeyboardInterrupt--

# %%
result_list[0].rsquared_adj
# Out:
# 0.9085022366274449

# %%
my_reduce2 = partial(pd.merge, how='outer')                                                              
df_final = reduce(my_reduce2, list_of_sensibilities)
df_final.index = funds
df_final.to_excel('assets/stress.xlsx')
df_final
# Out:
#                     BDRX      Bias     DOLAR      IBRX      ICO2      ICON  \
# 05448587000110 -0.323994  0.000657  0.177359  0.606254 -0.530986 -0.184220
# 11490618000101       NaN  0.000369 -0.187734       NaN -0.077601       NaN
# 01214092000175 -0.063436 -0.000363  0.156126  0.848016       NaN  0.661859
# 21624757000126  0.092413  0.000291       NaN       NaN  0.548725  0.916060
# 09528698000197       NaN  0.000254 -0.108859  1.106277  0.602862       NaN
# 19419157000184       NaN  0.000048       NaN       NaN       NaN       NaN
# 03168062000103       NaN  0.000504       NaN       NaN       NaN  0.096846
# 14812722000155  0.053055 -0.000033 -0.382513       NaN       NaN -0.101120
# 12987743000186 -0.504219 -0.000832       NaN       NaN       NaN       NaN
#
#                     IDIV       IEE      INDX       ISE  ...      UTIL  \
# 05448587000110 -0.850190 -0.632918 -0.396858  0.859206  ...  0.290085
# 11490618000101       NaN -0.201617       NaN       NaN  ...  0.151852
# 01214092000175       NaN       NaN -0.321027 -0.279566  ...  0.079009
# 21624757000126 -0.347130       NaN -0.381732 -0.307514  ...  0.205600
# 09528698000197 -0.151735 -0.145607 -0.052352  0.120453  ...       NaN
# 19419157000184 -1.436745 -0.953774       NaN  0.647188  ...  0.767979
# 03168062000103  0.195138       NaN       NaN       NaN  ...  0.359388
# 14812722000155 -0.141049       NaN       NaN -0.300049  ... -0.131201
# 12987743000186       NaN       NaN  0.965261       NaN  ...       NaN
#
#                     IBrA      IMAT     IVBX2      MLCX   IBRX_50      IFNC  \
# 05448587000110       NaN       NaN       NaN       NaN       NaN       NaN
# 11490618000101 -1.434079 -0.106760  0.215173  1.406696       NaN       NaN
# 01214092000175       NaN  0.240817       NaN -0.453782 -0.808685  0.367752
# 21624757000126       NaN  0.284969  0.077719       NaN -0.573568  0.524634
# 09528698000197       NaN       NaN -0.063919       NaN -0.240184 -0.062564
# 19419157000184       NaN       NaN -0.636429       NaN       NaN       NaN
# 03168062000103       NaN  0.114669       NaN       NaN       NaN       NaN
# 14812722000155  1.105690       NaN       NaN  0.722110 -0.866691 -0.458420
# 12987743000186       NaN       NaN  0.867353       NaN  0.630708       NaN
#
#                     IMOB      ITAG      IBOV
# 05448587000110       NaN       NaN       NaN
# 11490618000101       NaN       NaN       NaN
# 01214092000175       NaN       NaN       NaN
# 21624757000126 -0.014008 -0.942235       NaN
# 09528698000197       NaN -1.089702 -0.455547
# 19419157000184  0.489071  0.762367       NaN
# 03168062000103       NaN  0.341452       NaN
# 14812722000155  0.322749       NaN       NaN
# 12987743000186       NaN       NaN       NaN
#
# [9 rows x 21 columns]

# %%
dic_r2adj
# Out:
# {'05448587000110': 0.9782335055203004,
#  '11490618000101': 0.9978318730451738,
#  '01214092000175': 0.9981143162624325,
#  '21624757000126': 0.9867662220342057,
#  '09528698000197': 0.9918947608827021,
#  '19419157000184': 0.6395806409832192,
#  '03168062000103': 0.973828586781301,
#  '14812722000155': 0.9937672900174095,
#  '12987743000186': 0.9085022366274449}

# %%
i_fund = 8
result_list_2 = results_dict[funds[i_fund]]
df_topR2 = pd.DataFrame(result_list_2[0].coeffs_dict.values(), list(result_list_2[0].coeffs_dict.keys()))
for i in range(len(result_list_2)):
    continue
    if result_list_2[i].rsquared_adj < .9:
        break
    p_values = pd.DataFrame(result_list_2[i].coeffs_dict.values(), list(result_list_2[i].coeffs_dict.keys()))
    df_topR2 = pd.concat((df_topR2, p_values))
    
by_row_index = df_topR2.groupby(df_topR2.index)
df_means = by_row_index.mean()
print(df_means)

y = X_data[funds[i_fund]]
mean_fit = X_total_model[df_means.index].mul(pd.Series(df_means.to_dict()[0]), axis=1).sum(axis=1)

fig, ax = plt.subplots()
fittedValues = X_total_model[best_rsquaredAdj_obj.selected_dimensions].multiply(best_rsquaredAdj_obj.model.params.values).sum(axis=1).values
sns.scatterplot(range(len(y)), y, ax=ax)
sns.scatterplot(range(len(mean_fit)), mean_fit, marker='+', color='red', ax=ax)
# Out:
#                 0
# BDRX    -0.581345
# Bias    -0.001666
# IBRX     1.435838
# IBRX_50  0.630708
# ICO2     0.718116
# ICON     1.011297
# IEE     -1.004421
# IMAT     0.299607
# INDX     0.780031
# ISE      0.870645
# ITAG    -0.966068
# IVBX2    0.431842
# MLCX     0.882104
# SMLL     0.166253
# UTIL    -0.050144
